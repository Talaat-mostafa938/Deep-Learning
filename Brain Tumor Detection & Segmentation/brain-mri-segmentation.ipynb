# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv
import os
from PIL import Image
from tqdm import tqdm
from glob import glob


import tensorflow as tf
from tensorflow.keras.layers import Conv2D , MaxPooling2D , BatchNormalization , Conv2DTranspose , Concatenate ,  Input
from tensorflow.keras.models import Sequential , Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator


import warnings
warnings.filterwarnings('ignore')
# Out:
# 2025-08-04 22:34:32.620578: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754346872.823512      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754346872.887003      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
root = "/kaggle/input/lgg-mri-segmentation/kaggle_3m"

# %%
def create_data(path_data):
    images_paths = []
    masks_paths = glob(f'{path_data}/*/*_mask*')

    for i in masks_paths:
        images_paths.append(i.replace('_mask',''))

    return images_paths , masks_paths

# %%
images , masks = create_data(root)

# %%
print("images_len: ", len(images))
print("masks_len: ", len(masks))
# Out:
# images_len:  3929
# masks_len:  3929

# %%
plt.figure(figsize = (12 , 12))
for i in range(16):
    plt.subplot(4 , 4 , i+1)

    image = images[i]
    mask = masks[i]

    img = cv.imread(image)
    img = cv.cvtColor(img , cv.COLOR_BGR2RGB)

    mask = cv.imread(mask , cv.IMREAD_GRAYSCALE)

    plt.imshow(img)
    plt.imshow(mask , cmap = 'jet' , alpha = 0.5)
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
H = 256
W = 256
C = 3

# %%
def preprocessing_data():
    images_list = []
    masks_list = []

    for img_path, mask_path in zip(images, masks):
        img = cv.imread(img_path, cv.IMREAD_COLOR)
        mask = cv.imread(mask_path, cv.IMREAD_GRAYSCALE)

        if img is None or mask is None:
            print(f"Failed to load image or mask: {img_path} : {mask_path}")
            continue

        img = cv.resize(img, (H, W))
        mask = cv.resize(mask, (H, W))
        img = img/255.0
        mask = mask/255.0

        images_list.append(img)
        masks_list.append(mask)

    if not images_list:
        raise ValueError("No images or masks were loaded. Check file paths.")

    images_array = np.array(images_list)
    masks_array = np.array(masks_list)

    masks_array = np.expand_dims(masks_array, axis=-1)

    return images_array, masks_array

# %%
images, masks = preprocessing_data()

# %%
print('The Shape of X',images.shape)
print('The Shape of y',masks.shape)
# Out:
# The Shape of X (3929, 256, 256, 3)
# The Shape of y (3929, 256, 256, 1)

# %%
images = np.array(images , dtype = np.float32)
masks = np.array(masks , dtype = np.float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(images, masks, test_size=0.2, random_state=0)

print('The shape of X_train',X_train.shape)
print('The shape of y_train',y_train.shape)
print('The shape of X_test',X_test.shape)
print('The shape of y_test',y_test.shape)
# Out:
# The shape of X_train (3143, 256, 256, 3)
# The shape of y_train (3143, 256, 256, 1)
# The shape of X_test (786, 256, 256, 3)
# The shape of y_test (786, 256, 256, 1)

# %%
def build_unet(input_shape = (H , W , C)):
    inputs = Input(input_shape)
    # Encoder
    e1 = Conv2D(32 , (3,3) , activation = 'relu' , padding = 'same')(inputs)
    e1 = BatchNormalization()(e1)
    e1 = Conv2D(32 , (3,3) , activation = 'relu' , padding = 'same')(e1)
    e1 = BatchNormalization()(e1)
    p1 = MaxPooling2D((2,2))(e1)

    e2 = Conv2D(64 , (3,3) , activation = 'relu' , padding = 'same')(p1)
    e2 = BatchNormalization()(e2)
    e2 = Conv2D(64 , (3,3) , activation = 'relu' , padding = 'same')(e2)
    e2 = BatchNormalization()(e2)
    p2 = MaxPooling2D((2,2))(e2)

    e3 = Conv2D(128 , (3,3) , activation = 'relu' , padding = 'same')(p2)
    e3 = BatchNormalization()(e3)
    e3 = Conv2D(128 , (3,3) , activation = 'relu' , padding = 'same')(e3)
    e3 = BatchNormalization()(e3)
    p3 = MaxPooling2D((2,2))(e3)

    e4 = Conv2D(256 , (3,3) , activation = 'relu' , padding = 'same')(p3)
    e4 = BatchNormalization()(e4)
    e4 = Conv2D(256 , (3,3) , activation = 'relu' , padding = 'same')(e4)
    e4 = BatchNormalization()(e4)
    p4 = MaxPooling2D((2,2))(e4)

    # BottelNeck
    b1 = Conv2D(512 , (3,3) , activation = 'relu' , padding = 'same')(p4)
    b1 = BatchNormalization()(b1)
    b1 = Conv2D(512 , (3,3) , activation = 'relu' , padding = 'same')(b1)
    b1 = BatchNormalization()(b1)

    # Decoder
    d1 = Conv2DTranspose(256 , (2,2) , strides = (2,2), activation = 'relu' , padding = 'same')(b1)
    d1 = Concatenate()([d1 , e4])
    d1 = Conv2D(256 , (3,3) , activation = 'relu' , padding = 'same')(d1)
    d1 = BatchNormalization()(d1)
    d1 = Conv2D(256 , (3,3) , activation = 'relu' , padding = 'same')(d1)
    d1 = BatchNormalization()(d1)

    d2 = Conv2DTranspose(128 , (2,2) , strides = (2,2) , activation = 'relu' , padding = 'same')(d1)
    d2 = Concatenate()([d2 , e3])
    d2 = Conv2D(128 , (3,3) , activation = 'relu' , padding = 'same')(d2)
    d2 = BatchNormalization()(d2)
    d2 = Conv2D(128 , (3,3) , activation = 'relu' , padding = 'same')(d2)
    d2 = BatchNormalization()(d2)

    d3 = Conv2DTranspose(64 , (2,2) , strides = (2,2) , activation = 'relu' , padding = 'same')(d2)
    d3 = Concatenate()([d3 , e2])
    d3 = Conv2D(64 , (3,3) , activation = 'relu' , padding = 'same')(d3)
    d3 = BatchNormalization()(d3)
    d3 = Conv2D(64 , (3,3) , activation = 'relu' , padding = 'same')(d3)
    d3 = BatchNormalization()(d3)

    d4 = Conv2DTranspose(32 , (2,2) , strides = (2,2) , activation = 'relu' , padding = 'same')(d3)
    d4 = Concatenate()([d4 , e1])
    d4 = Conv2D(32 , (3,3) , activation = 'relu' , padding = 'same')(d4)
    d4 = BatchNormalization()(d4)
    d4 = Conv2D(32 , (3,3) , activation = 'relu' , padding = 'same')(d4)
    d4 = BatchNormalization()(d4)

    outputs = Conv2D(1 , (1,1) , activation = 'sigmoid')(d4)

    model = Model(inputs , outputs)

    return model

# %%
model = build_unet(input_shape=(H , W , C))
# Out:
# I0000 00:00:1754346967.402155      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=1e-5)

model.compile(optimizer = optimizer, loss='binary_crossentropy' , metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
earlystopping = EarlyStopping(monitor = 'val_loss', patience = 10)

# %%
history = model.fit(
    X_train, y_train,
    epochs = 20,
    batch_size = 32,
    validation_data = (X_test, y_test),
    callbacks = [earlystopping]
)
# Out:
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1754346994.616157      60 service.cc:148] XLA service 0x7b6a98002680 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1754346994.616880      60 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1754346996.401822      60 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1754347024.690381      60 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 98/99 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.5329 - loss: 0.8289
# E0000 00:00:1754347054.300951      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754347054.535191      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.5329 - loss: 0.8287
# E0000 00:00:1754347080.769435      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1754347081.006741      61 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 106s 592ms/step - accuracy: 0.5329 - loss: 0.8284 - val_accuracy: 0.0297 - val_loss: 0.7593
# Epoch 2/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.5483 - loss: 0.7530 - val_accuracy: 0.1697 - val_loss: 0.7859
# Epoch 3/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.5695 - loss: 0.7234 - val_accuracy: 0.1698 - val_loss: 0.8104
# Epoch 4/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.6017 - loss: 0.7059 - val_accuracy: 0.2164 - val_loss: 0.8062
# Epoch 5/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.6397 - loss: 0.6928 - val_accuracy: 0.3090 - val_loss: 0.7489
# Epoch 6/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.6728 - loss: 0.6804 - val_accuracy: 0.4862 - val_loss: 0.6962
# Epoch 7/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.7171 - loss: 0.6658 - val_accuracy: 0.7123 - val_loss: 0.6465
# Epoch 8/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.7493 - loss: 0.6538 - val_accuracy: 0.8400 - val_loss: 0.6175
# Epoch 9/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.7955 - loss: 0.6376 - val_accuracy: 0.8792 - val_loss: 0.5935
# Epoch 10/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.8279 - loss: 0.6223 - val_accuracy: 0.9040 - val_loss: 0.5661
# Epoch 11/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 288ms/step - accuracy: 0.8568 - loss: 0.6059 - val_accuracy: 0.9197 - val_loss: 0.5557
# Epoch 12/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.8801 - loss: 0.5948 - val_accuracy: 0.9264 - val_loss: 0.5551
# Epoch 13/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.8938 - loss: 0.5866 - val_accuracy: 0.9365 - val_loss: 0.5525
# Epoch 14/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9057 - loss: 0.5793 - val_accuracy: 0.9451 - val_loss: 0.5448
# Epoch 15/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9174 - loss: 0.5726 - val_accuracy: 0.9550 - val_loss: 0.5365
# Epoch 16/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9312 - loss: 0.5641 - val_accuracy: 0.9590 - val_loss: 0.5348
# Epoch 17/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9357 - loss: 0.5615 - val_accuracy: 0.9645 - val_loss: 0.5319
# Epoch 18/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9467 - loss: 0.5537 - val_accuracy: 0.9687 - val_loss: 0.5311
# Epoch 19/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9508 - loss: 0.5492 - val_accuracy: 0.9720 - val_loss: 0.5237
# Epoch 20/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 29s 289ms/step - accuracy: 0.9572 - loss: 0.5413 - val_accuracy: 0.9770 - val_loss: 0.5151

# %%
loss , accuarcy = model.evaluate(X_test , y_test)
print(f"The Loss : {loss}")
print(f"The accuarcy : {accuarcy}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.9769 - loss: 0.5157
# The Loss : 0.5150777101516724
# The accuarcy : 0.9770054817199707

# %%
predict_mask = model.predict(X_test)
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 148ms/step

# %%
predict_mask = (predict_mask > 0.5).astype(np.uint8)

# %%
for index in range(0 , 10):
    
    plt.figure(figsize=(12, 6))
    
    plt.subplot(1 , 3 , 1)
    plt.title('Original')
    img = cv.cvtColor(X_test[index] , cv.COLOR_BGR2RGB)
    plt.imshow(img)

    plt.subplot(1 , 3  ,2)
    plt.title('Mask')
    plt.imshow(y_test[index].squeeze() , cmap = 'gray')

    plt.subplot(1 , 3 , 3)
    plt.title('Predicted')
    plt.imshow(predict_mask[index].squeeze() , cmap = 'gray')
    
    plt.show()

# %%
img_path = '/kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_14.tif'

# %%
def predict_mask(img_path):
    img = cv.imread(img_path)
    if img is None:
        print(f"❌ Couldn't read image at {img_path}")
        return
    
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    img = cv.resize(img, (H, W))  
    img_input = img / 255.0  
    img_input = np.expand_dims(img_input, axis=0)

    pred = model.predict(img_input)[0]
    pred_mask = (pred > 0.5).astype(np.uint8) 

    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.title("Input Image")
    plt.imshow(img)

    plt.subplot(1,2,2)
    plt.title("Predicted Mask")
    plt.imshow(pred_mask.squeeze(), cmap='gray')

    plt.show()

# %%
predict_mask(img_path)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
model.save("brain_tumor_segmentation_model.keras")

# %%
from tensorflow.keras.models import load_model

model = load_model("brain_tumor_segmentation_model.keras")

# %%
from IPython.display import FileLink
FileLink("brain_tumor_segmentation_model.keras")
# Out:
# /kaggle/working/brain_tumor_segmentation_model.keras
